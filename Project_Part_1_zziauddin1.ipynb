# %% [markdown]
# <a href="https://colab.research.google.com/github/zar55/COSC_640_Intro_to_AI/blob/Nim-Final-Projct/Project_Part_1_zziauddin1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # COSC-640: Project (Part 1)
#
# **Zargham Ziauddin**
#
# [PLACEHOLDER_FOR_NOTEBOOK_LINK]

# %% [markdown]
# ## Getting Started
#
# Follow the instructions below to copy this notebook and to perform some initial setup.
#
# 1. Copy this notebook by selecting `File > Save a copy in Drive`.
# 2. A new window should open for the copied notebook. Move the new notebook to your course folder in Google Drive by selecting `File > Move` and then selecting the desired folder.
# 3. Update the name of the notebook by removing "Copy of" and replacing "Username" with your actual username.
# 4. Update the first cell in the notebook by replacing "**Student Name**" with your actual name.
# 5. Do not edit the line that says `PLACEHOLDER_FOR_NOTEBOOK_LINK`. This will be used by the [Notebook Renderer](https://colab.research.google.com/drive/1CJTipys46ldZxJFwnt7XbdjQUfkmoXeU?usp=sharing) tool to insert a link to your Colab notebook.
# 6. Enable link sharing for your notebook.

# %% [markdown]
# # Description of Part 1
#
#
# This notebook is provided to assist you in writing the `Nim` class for the course project. A template for the class is provided below. Your task is to complete the defintions for several methods in the class. Test code is provided later in the notebook to check your methods.
#
# Detailed descriptions of the methods can be found in the following document: [Nim Class Methods.pdf](https://drive.google.com/file/d/1lkLn-9rjXHk7NcKkmpL5lEOQ-lnI3Ci_/view?usp=sharing)
#
# It is strongly recommended that you complete the methods one at a time, in the order that they appear in the class, making sure that the relevant tests are passed by each method before moving on to the next method.
#
# When the entire notebook runs without any errors being generated by the tests, you can be reasonably confident that the class is implemented correctly.

# %% [markdown]
# # The Nim Class

# %%
import numpy as np

class Nim:

    def __init__(self, piles, stones, limit):
      self.piles = piles
      self.stones = stones
      self.limit = limit
      self.winner = None
      self.turns = 0
      self.cur_player = 1
      self.board = [self.stones]*self.piles

      pass


    def display(self):
      print(f"Current Turn: {self.turns}, Current Player: {self.cur_player}, Piles: {self.board}")

      pass


    def copy(self):
      new_node = Nim(piles=self.piles, stones=self.stones, limit=self.limit)

      new_node.winner = self.winner
      new_node.turns = self.turns
      new_node.cur_player = self.cur_player

      new_node.board = self.board.copy()

      return new_node

      pass


    def check_for_win(self):
      if all(stones == 0 for stones in self.board):
        self.winner = self.cur_player

      pass


    def get_actions(self):
      actions = []

      for pile_index, stones_in_pile in enumerate(self.board):
        max_stones = min(self.limit, stones_in_pile)

        for num_stones in range(1, max_stones + 1):
                actions.append((pile_index, num_stones))

      return actions

      pass

    def take_action(self, a):
      new_node = self.copy()

      pile_index, stones_removed = a
      new_node.board[pile_index] -= stones_removed

      new_node.turns += 1

      new_node.cur_player = 3 - new_node.cur_player

      new_node.check_for_win()

      return new_node

      pass


    def get_state(self):
        s = 0
        for i in range(self.piles):
            s += self.board[i] * (self.stones + 1) ** i
        return s

    def heuristic(self, agent, mode=None):
        return 0

# %% [markdown]
# # Test Code
#
# Run each of the cells below to test your implementation of the `Nim` class.
#
# As mentioned above, it is recommended that you complete the methods one at a time, in the order that they appear in the class, making sure that the relevant tests are passed by each method before moving on to the next method.
#
# When the entire notebook runs without any errors being generated by the tests, you can be reasonably confident that the class is implemented correctly.

# %% [markdown]
# ## `__init__()` Tests

# %%
nim = Nim(piles=3, stones=5, limit=4)

assert(nim.piles == 3)
assert(nim.stones == 5)
assert(nim.limit == 4)
assert(nim.winner is None)
assert(nim.turns == 0)
assert(nim.cur_player == 1)
assert(nim.board == [5,5,5])
print('All tests passed!')
# Out:
# All tests passed!

# %% [markdown]
# ## `display()` Tests

# %%
nim = Nim(piles=3, stones=5, limit=4)
nim.display()
# Out:
# Current Turn: 0, Current Player: 1, Piles: [5, 5, 5]

# %% [markdown]
# ## `copy()` Tests

# %%
nim = Nim(piles=3, stones=5, limit=4)
copy = nim.copy()
nim.board[2] += 1
assert(copy.piles == 3);
assert(copy.stones == 5)
assert(copy.limit == 4)
assert(copy.winner is None)
assert(copy.turns == 0)
assert(copy.cur_player == 1)
assert(copy.board == [5,5,5])
print('All tests passed!')
# Out:
# All tests passed!

# %% [markdown]
# ## `check_for_win()` Tests

# %%
nim = Nim(piles=3, stones=5, limit=3)
nim.check_for_win()
assert(nim.winner == None)

nim.cur_player = 1
nim.board = [0,0,0]
nim.check_for_win()
assert(nim.winner == 1)

nim.cur_player = 2
nim.check_for_win()
assert(nim.winner == 2)

print('All tests passed!')
# Out:
# All tests passed!

# %% [markdown]
# ## `get_actions()` Tests

# %%
nim = Nim(piles=2, stones=5, limit=3)
assert(set(nim.get_actions()) == set([(0,1),(0,2),(0,3),(1,1),(1,2),(1,3)]))

nim = Nim(piles=2, stones=5, limit=3)
nim.board[1] -= 3
assert(set(nim.get_actions()) == set([(0,1),(0,2),(0,3),(1,1),(1,2)]))

nim = Nim(piles=3, stones=5, limit=3)
nim.board[0] -= 5
nim.board[2] -= 4
nim.get_actions()
assert(set(nim.get_actions()) == set([(1,1),(1,2),(1,3),(2,1)]))

print('All tests passed!')
# Out:
# All tests passed!

# %% [markdown]
# ## `get_state()` Tests

# %%
nim = Nim(piles=2, stones=5, limit=3)
assert(nim.get_state() == 35)

nim = Nim(piles=2, stones=5, limit=3)
nim.board[1] -= 3
assert(nim.get_state() == 17)

nim = Nim(piles=3, stones=5, limit=3)
nim.board[0] -= 5
nim.board[2] -= 4
assert(nim.get_state() == 66)

print('All tests passed!')
# Out:
# All tests passed!

# %% [markdown]
# ## `take_action()` Tests

# %%
nim = Nim(piles=3, stones=5, limit=3)
nim = nim.take_action((1,4))

assert(nim.get_state() == 191)
assert(nim.turns == 1)
assert(nim.cur_player == 2)
assert(nim.winner is None)

print('All tests passed!')
# Out:
# All tests passed!

# %%
nim = Nim(piles=3, stones=5, limit=3)
nim = nim.take_action((0,2))
nim = nim.take_action((2,3))

assert(nim.get_state() == 105)
assert(nim.turns == 2)
assert(nim.cur_player == 1)
assert(nim.winner is None)

print('All tests passed!')
# Out:
# All tests passed!

# %%
nim = Nim(piles=3, stones=5, limit=3)
nim = nim.take_action((0,2))
nim = nim.take_action((2,3))
nim = nim.take_action((0,3))
nim = nim.take_action((1,1))

assert(nim.get_state() == 96)
assert(nim.turns == 4)
assert(nim.cur_player == 1)
assert(nim.winner is None)

print('All tests passed!')
# Out:
# All tests passed!

# %%
nim = Nim(piles=3, stones=5, limit=3)
nim = nim.take_action((0,2))
nim = nim.take_action((0,3))
nim = nim.take_action((1,2))
nim = nim.take_action((1,3))
nim = nim.take_action((2,1))
nim = nim.take_action((2,3))
nim = nim.take_action((2,1))

assert(nim.get_state() == 0)
assert(nim.turns == 7)
assert(nim.cur_player == 2)
assert(nim.winner == 2)

print('All tests passed!')
# Out:
# All tests passed!

# %% [markdown]
# ## `heuristic()` Test

# %%
nim = Nim(piles=3, stones=5, limit=3)
assert(nim.heuristic(agent=1) == 0)

# %% [markdown]
# # Submission Instructions
#
# 1. Perform a Restart and Run All by clicking **Tools > Restart session and run all**.
# 2. Copy the link to your notebook by clicking **Share > Copy Link**.
# 3. Paste the copied link into the `notebook_url` field in the [Notebook Renderer](https://colab.research.google.com/drive/1CJTipys46ldZxJFwnt7XbdjQUfkmoXeU?usp=sharing) tool and then execute the cell to render the notebook.
# 4. The Notebook Renderer will open up a save file dialog. Save the resulting HTML file yo your local machine.
# 5. Submit the HTML file to Canvas.
